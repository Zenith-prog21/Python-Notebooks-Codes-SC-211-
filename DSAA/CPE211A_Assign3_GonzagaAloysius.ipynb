# %% [markdown]
# # **CPE211 Programming Assignment 3**
# Submitted by: Gonzaga, Aloysius Q.

# %% [markdown]
# ## **T. Tuple**
#
# #### ***Discussion and Explanation:***

# %%
# Example 1:
t = (1, 2, 3)
print(t[0])

# Example 2:
t = ('a', True, 5)
print(t)
print(t[0])
print(t[1])
print(t[2])

# %%
# Example 3: A tuple is immutable. You cannot modify/change a tuple item.
t = ('a', True, 5)
print(t)
t[0] = 'b'
print(t)
print(t[0])

# %%
# Example 4: A list is mutable. You can modify/change a list item.
t = ['a', True, 5]
print(t)
t[0] = 'b'
print(t)
print(t[0])

# Example 5: A list of tuples.
mypairs = [(1, 2), (3, 4), (5, 6)]
for item in mypairs:
    print(item)

# %% [markdown]
# ## **U. Unpacking**
#
# #### ***Discussion and Explanation:***

# %%
# Example 1:
coordinates = (1, 2, 3)

a = coordinates[0]
b = coordinates[1]
c = coordinates[2]
print(f'x={a},y={b},z={c}')

x, y, z = coordinates
print(f'x={x},y={y},z={z}')

# Example 2: Iterate through a tuple and UNPACKING a tuple.
mypairs = [(1, 2), (3, 4), (5, 6)]
for (tup1, tup2) in mypairs:
    print(tup1)
    print(tup2)

# Example 3: Tuple UNPACKING.
mypairs = [(1, 2), (3, 4), (5, 6)]
for tup1, tup2 in mypairs:
    print(tup2)
    print(tup1)

# %%
# Q1 Problem Exercises

# %% [markdown]
# ## **V. Dictionary**
#
# #### ***Discussion and Explanation:***

# %%
# Example 1:
my_stuff = {'key1': 'value1', 'key2': 'value2', 'key3': 'value3'}
print(my_stuff)
print(my_stuff['key1'])
print(my_stuff['key2'])
print(my_stuff['key3'])

# Example 2: NESTED DICTIONARIES. Dictionary values may be any data types.
my_stuff = {'key1': 12, 'key2': 'stringValue', 'key3': {'key4': [3, 4, 5]}}
print(my_stuff)
print(my_stuff['key1'])
print(my_stuff['key2'])
print(my_stuff['key3'])
print(my_stuff['key3']['key4'])
print(my_stuff['key3']['key4'][0])
print(my_stuff['key3']['key4'][1])
print(my_stuff['key3']['key4'][2])

# Example 3: Using the GET method to retrieve the value at a key.
my_stuff = {'key1': 12, 'key2': 'stringValue', 'key3': {'key4': [3, 4, 5]}}
print(my_stuff)
print(my_stuff.get('key1'))
print(my_stuff.get('key2').upper())
print(my_stuff.get('key3'))
print(my_stuff.get('key3')['key4'])
print(my_stuff.get('key3').get('key4'))
print(my_stuff.get('key3').get('key4')[0])
print(my_stuff.get('key3').get('key4')[1])
print(my_stuff.get('key3').get('key4')[2])

# Example 4: Reassigning dictionary items/values.
my_diet = {'breakfast': 'eggs', 'lunch': 'veggies'}
print(my_diet)
my_diet['breakfast'] = 'tea'
print(my_diet)

# Example 5: Adding a new key-value pair to a dictionary.
my_diet = {'breakfast': 'eggs', 'lunch': 'veggies'}
print(my_diet)
my_diet['breakfast'] = 'tea'
my_diet['dinner'] = 'steamed salmon'
print(my_diet)

# Example 6: Iterate through a dictionary.
dict = {'Sam': 1, 'Frank': 2, 'Dan': 3}
for key in dict:
    print(key)
    print(dict[key])

# Example 7: Iterate through a dictionary.
dict = {'Sam': 1, 'Frank': 2, 'Dan': 3}
for k in dict.keys():
    print(k)

# Example 8: Iterate through a dictionary.
dict = {'Sam': 1, 'Frank': 2, 'Dan': 3}
for k in dict.values():
    print(k)

# Example 9:
customer = {
    'name': 'Juan Cruz',
    'age': 30,
    'is_verified': True
}

print(customer['name'])
print(customer.get('name'))
print(customer.get('address', 'USTP'))

customer['name'] = 'Maria Clara'
print(customer['name'])
customer['address'] = 'Divisoria, CdO'
print(customer['address'])

# %%
# Q2 Problem Exercises

# %% [markdown]
# ## **W. Set**
#
# #### ***Discussion and Explanation:***

# %%
# Example 1:
x = set()
x.add(1)
x.add(2)
x.add(3)
print(x)

# Example 2: Sets may have elements of mixed data types.
x = set()
x.add(3)
x.add(1)
x.add(5)
x.add(False)
x.add(2.8)
x.add(4)
x.add('hello')
print(x)

# Example 3: Sets have unique elements, no repetition of elements.
x = set()
x.add(3)
x.add(3)
x.add(1)
x.add(4)
x.add(2.5)
x.add(False)
x.add(1)
x.add('hello')
x.add(4)
x.add(2.5)
x.add(1)
x.add(False)
x.add(4)
x.add('hello')
print(x)

# Example 4: Sets have unique elements, no repetition of elements.
x = set([1, 1, 1, 1, 2, 2, 2, 3, 3, 3, 4, 4, 4, 5, 5, 5, 5])
print(x)

# Example 5: Sets have unique elements, no repetition of elements.
li = [1, 1, 1, 1, 2, 2, 2, 3, 3, 3, 4, 4, 4, 5, 5, 5, 5]
s = set(li)
print(s)

# %%
# Q3 Problem Exercises

# %% [markdown]
# ## **X. Function**
#
# #### ***Discussion and Explanation:***

# %%
# Example 1:
def greet_user():
    print('Hi there!')
    print('Welcome aboard.')


print('Start')
greet_user()
print('Finish')

# %%
# Example 2:
print('Start')
greet_user()
print('Finish')


def greet_user():
    print('Hi there!')
    print('Welcome aboard.')

# %% [markdown]
# - ### **Function Parameters**
#
#     #### ***Discussion and Explanation:***

# %%
# Example 1:
def greet_user(name):
    """
    DOCSTRING
    Describe the function here, specifying precondition & postcondition.
    """
    print(f'\nHi there, {name}!')
    print('Welcome aboard.')


print('Start')
greet_user('John')
greet_user('Mary')
print('Finish')

# Example 2:
def greet_user(fname, lname):
    print(f'\nHi there, {fname} {lname}!')
    print(f'Welcome aboard {fname[0]}.{lname[0]}.')


print('Start')
greet_user('Juan', 'Cruz')
greet_user('Maria', 'Clara')
print('Finish')

# Example 3:
def greet_user(fname, lname):
    print(f'\nHi there, {fname} {lname}!')
    print(f'Welcome aboard {fname[0]}.{lname[0]}.')


print('Start')
greet_user(lname='Cruz', fname='Juan')
greet_user(lname='Clara', fname='Maria')
print('Finish')

# %%
# Example 4: ERROR!
def greet_user(fname, lname):
    print(f'\nHi there, {fname} {lname}!')
    print(f'Welcome aboard {fname[0]}.{lname[0]}.')


print('Start')
greet_user(lname='Clara', 'Maria')
print('Finish')

# %%
# Example 5: CORRECT!
def greet_user(fname, lname):
    print(f'\nHi there, {fname} {lname}!')
    print(f'Welcome aboard {fname[0]}.{lname[0]}.')


greet_user('Maria', lname='Clara')

# %% [markdown]
# - ### **Return Statement**
#
#     #### ***Discussion and Explanation***

# %%
# Example 1:
def square(number):
    print(number * number)


print(square(6))

# Example 2:
def square(number):
    return number * number


result = square(6)
print(result)

# %% [markdown]
# - ### **Creating a Reusable Function**
#
#     #### ***Discussion and Explanation:***

# %% [markdown]
# - ### **Lambda Expression**
#
#     #### ***Discussion and Explanation:***

# %%
# Example 1:
mylist = [1, 2, 3, 4, 5, 6, 7, 8]


def even_bool(num):
    return num % 2 == 0


evens = filter(even_bool, mylist)
print(list(evens))

# Example 2: Using lambda expression
mylist = [1, 2, 3, 4, 5, 6, 7, 8]
evens = filter(lambda num: num % 2 == 0, mylist)
print(list(evens))

# %% [markdown]
# ## **Y. Exception**
#
# #### ***Discussion and Explanation:***

# %%
# Example 1: EXCEPTION/RUN-TIME ERROR!
age = int(input('Age: '))
print(age)

# %%
# Example 2: Using try-except block to catch and handle exception.
try:
    age = int(input('Age: '))
    print(age)
except ValueError:
    print('Invalid age input.')

# %%
# Example 3: ANOTHER EXCEPTION/RUN-TIME ERROR!
try:
    age = int(input('Age: '))
    income = 20000
    risk = income / age
    print(age)
except ValueError:
    print('Invalid age input.')

# %%
# Example 4: Add a second except block to catch and handle the second exception.
try:
    age = int(input('Age: '))
    income = 20000
    risk = income / age
    print(age)
except ValueError:
    print('Invalid age input.')
except ZeroDivisionError:
    print('Age cannot be zero.')

# %% [markdown]
# - ### **Name Variable Scope**
#
#     #### ***Discussion and Explanation:***

# %%
# Example 1:
x = 25


def my_func():
    x = 50
    return x


print(x)
print(my_func())
print(x)

# Example 2: Local variable is used.
name = 'This is a global name!'


def greet():
    name = 'Sammy'

    def hello():
        print('hello ' + name)

    hello()


greet()

# Example 3: Without local variable, global variable is used.
name = 'This is a global name!'


def greet():
    def hello():
        print('hello ' + name)

    hello()


greet()

# Example 4:
name = 'This is a global name!'


def greet():
    name = 'Sammy'

    def hello():
        print('hello ' + name)

    hello()


greet()
print(name)

# Example 5:
x = 50


def func(x):
    print('local x is:', x)
    x = 100
    print('local x is changed to:', x)


print('global x is:', x)
func(x)
print('global x is:', x)

# Example 6: Accessing a global variable inside a function using the global keyword.
x = 50


def func():
    global x
    x = 100
    print('inside the function, global x is changed to:', x)


print('before function call, global x is:', x)
func()
print('after function call, global x is:', x)

# Example 7: Same effect without using the global keyword inside a function.
x = 50


def func():
    x = 100
    return x


print('before function call, global x is:', x)
x = func()
print('after function call, global x is:', x)

# Example 8:
s = 'hello'
print(s)
print(len(s))

# %%
# Example 9: Reassigning a value for built-in name len will override the built-in function len.
len = 3
s = 'hello'
print(len)
print(s)
print(len(s))

# %% [markdown]
# ## **Z. Class**
#
# #### ***Discussion and Explanation:***

# %%
# Example 1:
class Sample:
    pass


c = Sample()
d = Sample()
print(type(Sample))
print(type(c))
print(type(d))

# Example 2:
class Point:
    def move(self):
        print('move')

    def draw(self):
        print('draw')


point1 = Point()
point1.draw()
point1.move()

# %%
# Example 3:
class Point:
    def move(self):
        print('move')

    def draw(self):
        print('draw')


point1 = Point()
point1.x = 10
point1.y = 20
print(f'point1 = ({point1.x},{point1.y})')
point1.draw()
point1.move()

point2 = Point()
print(f'point2 = ({point2.x},{point2.y})')
point2.draw()
point2.move()

# %%
# Example 4:
class Point:
    def move(self):
        print('move')

    def draw(self):
        print('draw')


point1 = Point()
point1.x = 10
point1.y = 20
print(f'point1 = ({point1.x},{point1.y})')
point1.draw()
point1.move()

point2 = Point()
point2.w = 1
point2.z = 2
print(f'point2 = ({point2.w},{point2.z})')
point2.draw()
point2.move()

# %% [markdown]
# - ### **Constructor**
#
#     #### ***Discussion and Explanation:***

# %%
# Example 1:
class Point:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def move(self):
        print('move')

    def draw(self):
        print('draw')


point1 = Point(10, 20)
print(f'point1 = ({point1.x},{point1.y})')
point1.draw()
point1.move()

point2 = Point(15, 25)
print(f'point2 = ({point2.x},{point2.y})')
point2.draw()
point2.move()

# Example 2:
class Point:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def move(self):
        print('move')

    def draw(self):
        print('draw')


point1 = Point(10, 20)
print(f'point1 = ({point1.x},{point1.y})')
point1.draw()
point1.move()
point1.x = 11
point1.y = 21
print(f'point1 = ({point1.x},{point1.y})')

point2 = Point(15, 25)
print(f'\npoint2 = ({point2.x},{point2.y})')
point2.draw()
point2.move()
point2.x = 16
point2.y = 26
print(f'point1 = ({point2.x},{point2.y})')

# Example 3:
class Dog:
    def __init__(self, breed):
        self.breed = breed


sam = Dog(breed='Labrador')
frank = Dog('Husky')
print(sam.breed)
print(frank.breed)

# Example 4: Class Object Attribute - common attribute with same value for all instances.
class Dog:
    species = 'mammal'

    def __init__(self, breed, name, age):
        self.breed = breed
        self.name = name
        self.age = age


dog1 = Dog('Labrador', 'Max', 4)
dog2 = Dog('Husky', name='Beauty', age=7)
dog3 = Dog('Shih Tzu', age=3, name='Chiku')

print('%10s %10s %10s %10s' % ('Name', 'Breed', 'Age', 'Species'))
print('%10s %10s %10d %10s' % (dog1.name, dog1.breed, dog1.age, dog1.species))
print('%10s %10s %10d %10s' % (dog2.name, dog2.breed, dog2.age, dog2.species))
print('%10s %10s %10d %10s' % (dog3.name, dog3.breed, dog3.age, dog3.species))

# Example 5:
class Circle:
    pi = 3.14

    def __init__(self, radius=1):
        self.radius = radius

    def area(self):
        return self.radius * self.radius * Circle.pi

    def setRadius(self, radius):
        self.radius = radius

    def getRadius(self):
        return self.radius


c = Circle()
print("Circle's pi = ", Circle.pi)
print('Radius is: ', c.getRadius())
print('Radius is: ', c.radius)
c.setRadius(2)
print('Radius is: ', c.getRadius())
print('Area is: ', c.area())

# Example 6:
class Person:
    def __init__(self, n):
        self.name = n

    def talk(self, person2):
        print(f'{self.name} talks with {person2}.')


p1 = Person('Juan dela Cruz')
p2 = Person('Maria Clara')
p1.talk(p2.name)
p2.talk(p1.name)

# %% [markdown]
# - ### **Inheritance**
#
#     #### ***Discussion and Explanation:***

# %%
# Example 1:
class Mammal:
    def walk(self):
        print('-mammals walk')

    def distinguishing_char(self):
        print('-has mammary glands')


class Dog(Mammal):
    def bark(self):
        print('-bark at strangers')


class Cat(Mammal):
    def annoying(self):
        print('-annoying to humans')


dog = Dog()
cat = Cat()

print('Dog characteristics:')
dog.walk()
dog.distinguishing_char()
dog.bark()

print('\nCat characteristics:')
cat.walk()
cat.distinguishing_char()
cat.annoying()

# Example 2: INHERITANCE, OVERRIDING
class Person:
    def __init__(self, id, name, addr, phone):
        self.init_common(id, name, addr, phone)

    def init_common(self, id, name, addr, phone):
        self.id = id
        self.name = name
        self.addr = addr
        self.phone = phone

    def compute_community_tax(self):
        print('P 50.00')


class Student(Person):
    def __init__(self, id, name, addr, phone, course, year_level, units):
        self.init_common(id, name, addr, phone)
        self.course = course
        self.year_level = year_level
        self.units = units

    def compute_community_tax(self):
        print('P 5.00')


class Employee(Person):
    def __init__(self, id, name, addr, phone, job_title, rate, hrs_worked):
        self.init_common(id, name, addr, phone)
        self.job_title = job_title
        self.rate = rate
        self.hrs_worked = hrs_worked

    def compute_community_tax(self):
        annual_income = self.rate * 12
        tax = annual_income * 0.1
        print(f'P {tax:.2f}')


class NonEmployee(Person):
    pass


stud = Student('2018-0120', 'Maria Clara', 'Lapasan', '09173334444', 'bscpe', 2, 18)
emp = Employee('2015-0777', 'Juan Cruz', 'Gusa', '09187778888', 'Programmer', 45000, 40)
non_emp = NonEmployee('01234567', 'John Doe', 'Divisoria', '09205551111')

print('Community Tax Computation:')
print('Student: ')
stud.compute_community_tax()
print('Employee: ')
emp.compute_community_tax()
print('Non-Employee: ')
non_emp.compute_community_tax()
